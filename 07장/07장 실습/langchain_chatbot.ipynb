# %% [markdown]
# # 랭체인 챗봇 만들기
# - LangChain과 OpenAI 모델을 사용하여 기본적인 챗봇 구현
# - 챗봇이 메모리를 갖지 않는 상태 확인

# %% [markdown]
# ## 필요 라이브러리 설치

# %%
# %pip install langchain langchain-openai
# Out:
# Requirement already satisfied: langchain in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (1.0.3)
# Requirement already satisfied: langchain-openai in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (1.0.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain) (1.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain) (2.11.9)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (0.4.40)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.11.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-openai) (2.7.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.11.0)
# Requirement already satisfied: sniffio in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.18)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.5.0)
# Requirement already satisfied: colorama in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## API KEY 불러오기

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

# %%
load_dotenv()
#api_key = os.getenv("OPEN_API_KEY")  # 환경 변수에서 API 키 가져오기
#client = OpenAI(api_key=api_key)  # 오픈AI 클라이언트의 인스턴스 생성
# Out:
# True

# %% [markdown]
# ## 모델 선언

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o-mini")

# %% [markdown]
# ## 첫 번째 대화

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="안녕? 나는 김건우야.")])
# Out:
# AIMessage(content='안녕하세요, 김건우님! 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 16, 'total_tokens': 31, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CY14tHIGQrGWHrhcCNL3SSdfKvQns', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--5a1a1c99-2557-4c33-9076-962a632cfe66-0', usage_metadata={'input_tokens': 16, 'output_tokens': 15, 'total_tokens': 31, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## 두 번째 대화

# %%
model.invoke([HumanMessage(content="내 이름이 뭐지?")])
# Out:
# AIMessage(content='죄송하지만, 당신의 이름을 알 수 있는 정보가 없습니다. 이름이 무엇인지 말씀해 주시면 도와드릴 수 있습니다!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 13, 'total_tokens': 43, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CY14uFjRQPgFsTb8JaQDJhbfMDFY7', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--635d395c-9a06-427b-a51a-cc18953054d1-0', usage_metadata={'input_tokens': 13, 'output_tokens': 30, 'total_tokens': 43, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
