# %% [markdown]
# # 자동화된 소프트웨어 개발팀 에이전트 만들기

# %% [markdown]
# ## 필요 라이브러리 설치

# %%
# %pip install langgraph
# Out:
# Requirement already satisfied: langgraph in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (1.0.2)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph) (1.0.4)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph) (3.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph) (0.2.9)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph) (2.11.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.11.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.4)
# Requirement already satisfied: anyio in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (4.10.0)
# Requirement already satisfied: certifi in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core>=0.1->langgraph) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core>=0.1->langgraph) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core>=0.1->langgraph) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gunwo\anaconda3\envs\test\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 필요 라이브러리 불러오기

# %%
import os
from typing import TypedDict, Annotated, Literal
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
from langgraph.graph import StateGraph, END, START

# %% [markdown]
# ## GPT 모델 설정

# %%
from dotenv import load_dotenv
load_dotenv()

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)

# %% [markdown]
# ## 상태 정의
# - 각 에이전트가 공유할 데이터 스키마

# %%
class State(TypedDict):
    requirement: str  # 사용자 요청 사항
    plan: str         # PM이 작성한 기획서
    code: str         # 개발자가 작성한 코드
    review: str       # 리뷰어의 피드백
    decision: str     # 리뷰 결과
    count: int        # 반복 횟수

# %% [markdown]
# ## 노드 정의

# %%
# PM 노드 함수
def pm_node(state: State):
    print("\n[PM] 기획서 작성 중")
    requirement = state["requirement"]

    # PM 에이전트 시스템 프롬프트 작성
    prompt = f"사용자의 요청: '{requirement}'\n이 요청을 바탕으로 소프트웨어 개발을 위한 간단한 기획서를 작성해줘"
    response = llm.invoke([SystemMessage(content="너는 유능한 IT PM이야"), HumanMessage(content=prompt)])

    return {"plan": response.content, "count": 1}

# %%
# 개발자 노드 함수
def coder_node(state: State):
    print("\n[Coder] 코드 작성 혹은 수정 중")
    plan = state["plan"]
    review = state.get("review", "") # 이전 리뷰가 있다면 가져옴

    # 개발자 에이전트 시스템 프롬프트 작성
    if review:
        prompt = f"기획서: {plan}\n\n리뷰어 피드백: {review}\n\n피드백을 반영하여 코드를 수정해줘."
    else:
        prompt = f"기획서: {plan}\n\n이 기획서에 맞춰 파이썬 코드를 작성해줘."

    response = llm.invoke([SystemMessage(content="너는 숙련된 파이썬 개발자야. 코드만 깔끔하게 출력해줘."), HumanMessage(content=prompt)])

    return {"code": response.content}

# %% [markdown]
# - 리뷰어 에이전트를 통해 그래프의 순환 구조를 확인하기 위해 2번까지 거절

# %%
# 리뷰어 노드 함수
def reviewer_node(state: State):
    print("\n[Reviewer] 코드 검토 중")
    code = state["code"]
    count = state["count"]

    if count > 3: # 3번 이상 반복되면 강제 승인 (무한 루프 방지)
        return {"decision": "approve", "review": "반복 횟수 초과로 승인합니다."}

    # 리뷰어 에이전트 시스템 프롬프트 작성
    prompt = f"다음 코드를 검토해줘:\n{code}\n\n버그가 있거나 개선이 필요하면 'REJECT'로 시작하는 피드백을 주고, 완벽하면 'APPROVE'라고만 답해."
    response = llm.invoke([SystemMessage(content="너는 꼼꼼한 코드 리뷰어야."), HumanMessage(content=prompt)])

    review_content = response.content
    decision = "approve" if "APPROVE" in review_content.upper() else "reject"
    print(f"--> 판정: {decision}")

    return {"decision" : "reject", "review" : f"테스트상 {count}번 재검토 합니다.", "count" : count +1}
    # return {"decision": decision, "review": review_content, "count": count + 1}

# %% [markdown]
# ## 그래프 정의
# - StateGraph를 생성할 때 상태의 스키마로 State 전달
# - 그래프가 처리할 데이터의 형태를 정의

# %%
graph = StateGraph(State)

# %% [markdown]
# ## 노드 정의

# %%
graph.add_node("PM", pm_node)
graph.add_node("Coder", coder_node)
graph.add_node("Reviewer", reviewer_node)

# %% [markdown]
# ## 엣지 정의

# %%
graph.add_edge(START, "PM")
graph.add_edge("PM", "Coder")
graph.add_edge("Coder", "Reviewer")

# %% [markdown]
# ### 조건부 엣지 함수 정의
# - `Literal` : `typing` 모듈 기능으로 변수나 반환 값이 특정 값들 중 하나만 가질 수 있음을 제한함

# %%
def check_review(state: State) -> Literal["Coder", "end"]:
    if state["decision"] == "approve":
        return "end"
    return "Coder"

# %% [markdown]
# ### Reviewer의 결정에 따라 분기하는 조건부 엣지 추가

# %%
graph.add_conditional_edges(
    "Reviewer",
    check_review,
    {
        "Coder": "Coder",
        "end": END
    }
)

# 그래프 컴파일
app = graph.compile()

# %% [markdown]
# ## 그래프 시각화

# %%
from IPython.display import Image, display

try:
    display(Image(app.get_graph().draw_mermaid_png()))
except Exception as e:
    pass

# %% [markdown]
# ## 그래프 실행

# %%
inputs = {"requirement": "테트리스 게임을 파이썬으로 만들어줘"}
final_code = ""
for output in app.stream(inputs):
    for key, value in output.items():
        print(f"Finished: {key}\n {value}")
        if "code" in value:
                final_code = value["code"]

# 최종 결과 확인
print("\n[최종 완성 코드]")
print(final_code)
# Out:
# [PM] 기획서 작성 중
# Finished: PM
#  {'plan': '# 테트리스 게임 개발 기획서\n\n## 1. 프로젝트 개요\n- **프로젝트명**: 파이썬 테트리스 게임\n- **목표**: 파이썬을 사용하여 기본적인 테트리스 게임을 구현한다.\n- **대상 플랫폼**: PC (Windows, macOS, Linux)\n- **개발 언어**: Python\n- **사용 라이브러리**: Pygame\n\n## 2. 기능 요구사항\n### 2.1 기본 기능\n- **게임 시작/종료**: 사용자는 게임을 시작하고 종료할 수 있어야 한다.\n- **점수 시스템**: 사용자는 블록을 쌓아 완성된 줄에 따라 점수를 얻는다.\n- **블록 생성**: 다양한 모양의 블록(Tetrimino)을 랜덤으로 생성한다.\n- **블록 이동 및 회전**: 사용자는 블록을 좌우로 이동시키고, 회전할 수 있어야 한다.\n- **자동 하강**: 블록은 일정 시간마다 아래로 자동으로 하강한다.\n- **라인 클리어**: 한 줄이 완성되면 삭제되고 점수가 증가한다.\n- **게임 오버**: 블록이 화면 상단에 도달할 경우 게임이 종료된다.\n\n### 2.2 추가 기능 (선택 사항)\n- **레벨 시스템**: 게임 진행에 따라 난이도가 증가하는 레벨 시스템 구현.\n- **사운드 효과**: 블록이 생성되거나 줄이 클리어될 때 사운드 효과 추가.\n- **일시 정지 기능**: 사용자가 게임을 일시 정지할 수 있는 기능.\n- **게임 기록 저장**: 사용자의 최고 점수를 저장하고 표시하는 기능.\n\n## 3. 기술 스택\n- **프로그래밍 언어**: Python\n- **게임 라이브러리**: Pygame\n- **버전 관리**: Git\n- **IDE**: Visual Studio Code, PyCharm 등\n\n## 4. 개발 일정\n| 단계          | 기간                  | 내용                             |\n|---------------|-----------------------|----------------------------------|\n| 기획          | 1주                   | 요구사항 정리 및 설계          |\n| 개발          | 2주                   | 기본 기능 구현                 |\n| 테스트        | 1주                   | 기능 테스트 및 버그 수정      |\n| 배포          | 1주                   | 최종 점검 및 배포              |\n\n## 5. 역할 분담\n- **PM (프로젝트 매니저)**: 프로젝트 전반 관리 및 일정 조율\n- **개발자**: 기능 구현 및 테스트\n- **디자이너 (선택 사항)**: UI/UX 디자인 (게임 화면, 버튼 등)\n\n## 6. 리스크 관리\n- **기술적 리스크**: Pygame의 기능 이해 부족으로 인한 개발 지연. 해결 방안: Pygame 문서 참고 및 튜토리얼 학습.\n- **시간 관리**: 일정 지연으로 인한 프로젝트 일정 변경. 해결 방안: 주간 회의를 통해 진행 상황 점검 및 조율.\n\n## 7. 결론\n본 기획서는 파이썬으로 테트리스 게임을 개발하기 위한 기본적인 방향성을 제시합니다. 본 프로젝트를 통해 프로그래밍 실력을 향상시키고, 재미있는 게임을 제공합니다. 개발이 완료된 후에는 피드백을 받아 개선할 수 있는 기회를 마련합니다.', 'count': 1}
#
# [Coder] 코드 작성 혹은 수정 중
# Finished: Coder
#  {'code': '```python\nimport pygame\nimport random\n\n# 초기화\npygame.init()\n\n# 상수 정의\nSCREEN_WIDTH, SCREEN_HEIGHT = 300, 600\nBLOCK_SIZE = 30\nFPS = 10\n\n# 색상 정의\nBLACK = (0, 0, 0)\nWHITE = (255, 255, 255)\nCOLORS = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0)]\n\n# 모양 정의\nSHAPES = [\n    [[1, 1, 1, 1]],  # I\n    [[1, 1], [1, 1]],  # O\n    [[0, 1, 0], [1, 1, 1]],  # T\n    [[1, 1, 0], [0, 1, 1]],  # Z\n    [[0, 1, 1], [1, 1, 0]],  # S\n]\n\nclass Tetrimino:\n    def __init__(self):\n        self.shape = random.choice(SHAPES)\n        self.color = random.choice(COLORS)\n        self.x = SCREEN_WIDTH // BLOCK_SIZE // 2 - len(self.shape[0]) // 2\n        self.y = 0\n\n    def rotate(self):\n        self.shape = [list(row) for row in zip(*self.shape[::-1])]\n\ndef draw_board(screen, board):\n    for y, row in enumerate(board):\n        for x, value in enumerate(row):\n            if value:\n                pygame.draw.rect(screen, value, (x * BLOCK_SIZE, y * BLOCK_SIZE, BLOCK_SIZE, BLOCK_SIZE))\n\ndef check_collision(board, shape, offset):\n    for y, row in enumerate(shape):\n        for x, value in enumerate(row):\n            if value:\n                if (x + offset[0] < 0 or x + offset[0] >= len(board[0]) or \n                    y + offset[1] >= len(board) or \n                    board[y + offset[1]][x + offset[0]]):\n                    return True\n    return False\n\ndef merge(board, shape, offset):\n    for y, row in enumerate(shape):\n        for x, value in enumerate(row):\n            if value:\n                board[y + offset[1]][x + offset[0]] = shape[y][x]\n\ndef clear_lines(board):\n    lines_cleared = 0\n    for y in range(len(board)):\n        if all(board[y]):\n            del board[y]\n            board.insert(0, [0] * len(board[0]))\n            lines_cleared += 1\n    return lines_cleared\n\ndef main():\n    screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))\n    clock = pygame.time.Clock()\n    board = [[0] * (SCREEN_WIDTH // BLOCK_SIZE) for _ in range(SCREEN_HEIGHT // BLOCK_SIZE)]\n    current_piece = Tetrimino()\n    score = 0\n\n    running = True\n    while running:\n        screen.fill(BLACK)\n        draw_board(screen, board)\n\n        for event in pygame.event.get():\n            if event.type == pygame.QUIT:\n                running = False\n\n        keys = pygame.key.get_pressed()\n        if keys[pygame.K_LEFT]:\n            if not check_collision(board, current_piece.shape, (current_piece.x - 1, current_piece.y)):\n                current_piece.x -= 1\n        if keys[pygame.K_RIGHT]:\n            if not check_collision(board, current_piece.shape, (current_piece.x + 1, current_piece.y)):\n                current_piece.x += 1\n        if keys[pygame.K_DOWN]:\n            if not check_collision(board, current_piece.shape, (current_piece.x, current_piece.y + 1)):\n                current_piece.y += 1\n        if keys[pygame.K_UP]:\n            current_piece.rotate()\n            if check_collision(board, current_piece.shape, (current_piece.x, current_piece.y)):\n                current_piece.rotate()  # Rotate back if collision\n\n        if not check_collision(board, current_piece.shape, (current_piece.x, current_piece.y + 1)):\n            current_piece.y += 1\n        else:\n            merge(board, current_piece.shape, (current_piece.x, current_piece.y))\n            score += clear_lines(board)\n            current_piece = Tetrimino()\n            if check_collision(board, current_piece.shape, (current_piece.x, current_piece.y)):\n                print("Game Over! Score:", score)\n                running = False\n\n        pygame.draw.rect(screen, current_piece.color, (current_piece.x * BLOCK_SIZE, current_piece.y * BLOCK_SIZE, BLOCK_SIZE, BLOCK_SIZE))\n        pygame.display.flip()\n        clock.tick(FPS)\n\n    pygame.quit()\n\nif __name__ == "__main__":\n    main()\n```'}
#
# [Reviewer] 코드 검토 중
# --> 판정: reject
# Finished: Reviewer
#  {'decision': 'reject', 'review': '테스트상 1번 재검토 합니다.', 'count': 2}
#
# [Coder] 코드 작성 혹은 수정 중
# Finished: Coder
#  {'code': '```python\nimport pygame\nimport random\n\n# 게임 설정\nWIDTH, HEIGHT = 300, 600\nBLOCK_SIZE = 30\nFPS = 10\n\n# 색상 정의\nCOLORS = [\n    (0, 0, 0),    # 빈 공간\n    (255, 0, 0),  # 빨강\n    (0, 255, 0),  # 초록\n    (0, 0, 255),  # 파랑\n    (255, 255, 0),# 노랑\n    (255, 165, 0),# 주황\n    (128, 0, 128),# 보라\n    (0, 255, 255) # 청록\n]\n\n# 테트리미노 모양\nSHAPES = [\n    [[1, 1, 1, 1]],  # I\n    [[1, 1], [1, 1]],  # O\n    [[0, 1, 0], [1, 1, 1]],  # T\n    [[1, 0, 0], [1, 1, 1]],  # L\n    [[0, 0, 1], [1, 1, 1]],  # J\n    [[1, 1, 0], [0, 1, 1]],  # S\n    [[0, 1, 1], [1, 1, 0]]   # Z\n]\n\n# 게임 클래스\nclass Tetris:\n    def __init__(self):\n        self.board = [[0] * (WIDTH // BLOCK_SIZE) for _ in range(HEIGHT // BLOCK_SIZE)]\n        self.current_piece = self.new_piece()\n        self.score = 0\n\n    def new_piece(self):\n        shape = random.choice(SHAPES)\n        color = COLORS[SHAPES.index(shape) + 1]\n        return {\'shape\': shape, \'color\': color, \'x\': 3, \'y\': 0}\n\n    def rotate_piece(self):\n        self.current_piece[\'shape\'] = [list(row) for row in zip(*self.current_piece[\'shape\'][::-1])]\n\n    def move_piece(self, dx):\n        self.current_piece[\'x\'] += dx\n\n    def drop_piece(self):\n        self.current_piece[\'y\'] += 1\n\n    def clear_lines(self):\n        lines_cleared = 0\n        for i in range(len(self.board) - 1, -1, -1):\n            if all(self.board[i]):\n                del self.board[i]\n                self.board.insert(0, [0] * (WIDTH // BLOCK_SIZE))\n                lines_cleared += 1\n        self.score += lines_cleared\n\n# Pygame 초기화\npygame.init()\nscreen = pygame.display.set_mode((WIDTH, HEIGHT))\npygame.display.set_caption("Tetris")\nclock = pygame.time.Clock()\n\n# 게임 루프\ndef main():\n    game = Tetris()\n    running = True\n\n    while running:\n        screen.fill((255, 255, 255))\n        for event in pygame.event.get():\n            if event.type == pygame.QUIT:\n                running = False\n            if event.type == pygame.KEYDOWN:\n                if event.key == pygame.K_LEFT:\n                    game.move_piece(-1)\n                if event.key == pygame.K_RIGHT:\n                    game.move_piece(1)\n                if event.key == pygame.K_UP:\n                    game.rotate_piece()\n                if event.key == pygame.K_DOWN:\n                    game.drop_piece()\n\n        game.drop_piece()\n        game.clear_lines()\n\n        # Draw the current piece\n        for y, row in enumerate(game.current_piece[\'shape\']):\n            for x, value in enumerate(row):\n                if value:\n                    pygame.draw.rect(screen, game.current_piece[\'color\'],\n                                     (game.current_piece[\'x\'] * BLOCK_SIZE + x * BLOCK_SIZE,\n                                      game.current_piece[\'y\'] * BLOCK_SIZE + y * BLOCK_SIZE,\n                                      BLOCK_SIZE, BLOCK_SIZE))\n\n        pygame.display.flip()\n        clock.tick(FPS)\n\n    pygame.quit()\n\nif __name__ == "__main__":\n    main()\n```'}
#
# [Reviewer] 코드 검토 중
# --> 판정: reject
# Finished: Reviewer
#  {'decision': 'reject', 'review': '테스트상 2번 재검토 합니다.', 'count': 3}
#
# [Coder] 코드 작성 혹은 수정 중
# Finished: Coder
#  {'code': '```python\nimport pygame\nimport random\n\n# 초기화\npygame.init()\n\n# 전역 상수\nSCREEN_WIDTH = 300\nSCREEN_HEIGHT = 600\nBLOCK_SIZE = 30\nFPS = 10\n\n# 색상 정의\nBLACK = (0, 0, 0)\nWHITE = (255, 255, 255)\nCOLORS = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0), (255, 165, 0)]\n\n# 테트리미노 클래스\nclass Tetromino:\n    shapes = [\n        [[1, 1, 1, 1]],  # I\n        [[1, 1], [1, 1]],  # O\n        [[0, 1, 0], [1, 1, 1]],  # T\n        [[1, 1, 0], [0, 1, 1]],  # S\n        [[0, 1, 1], [1, 1, 0]],  # Z\n        [[1, 0, 0], [1, 1, 1]],  # L\n        [[0, 0, 1], [1, 1, 1]]   # J\n    ]\n\n    def __init__(self):\n        self.shape = random.choice(Tetromino.shapes)\n        self.color = random.choice(COLORS)\n        self.x = SCREEN_WIDTH // BLOCK_SIZE // 2 - len(self.shape[0]) // 2\n        self.y = 0\n\n# 게임 클래스\nclass Tetris:\n    def __init__(self):\n        self.screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))\n        pygame.display.set_caption("Tetris")\n        self.clock = pygame.time.Clock()\n        self.grid = [[0] * (SCREEN_WIDTH // BLOCK_SIZE) for _ in range(SCREEN_HEIGHT // BLOCK_SIZE)]\n        self.current_tetromino = Tetromino()\n        self.score = 0\n        self.running = True\n\n    def draw_grid(self):\n        for y in range(len(self.grid)):\n            for x in range(len(self.grid[y])):\n                color = WHITE if self.grid[y][x] == 0 else self.grid[y][x]\n                pygame.draw.rect(self.screen, color, (x * BLOCK_SIZE, y * BLOCK_SIZE, BLOCK_SIZE, BLOCK_SIZE), 0)\n\n    def draw_tetromino(self):\n        for y, row in enumerate(self.current_tetromino.shape):\n            for x, block in enumerate(row):\n                if block:\n                    pygame.draw.rect(self.screen, self.current_tetromino.color, \n                                     ((self.current_tetromino.x + x) * BLOCK_SIZE, \n                                      (self.current_tetromino.y + y) * BLOCK_SIZE, \n                                      BLOCK_SIZE, BLOCK_SIZE), 0)\n\n    def check_collision(self):\n        for y, row in enumerate(self.current_tetromino.shape):\n            for x, block in enumerate(row):\n                if block:\n                    if (self.current_tetromino.x + x < 0 or\n                        self.current_tetromino.x + x >= len(self.grid[0]) or\n                        self.current_tetromino.y + y >= len(self.grid) or\n                        self.grid[self.current_tetromino.y + y][self.current_tetromino.x + x]):\n                        return True\n        return False\n\n    def merge_tetromino(self):\n        for y, row in enumerate(self.current_tetromino.shape):\n            for x, block in enumerate(row):\n                if block:\n                    self.grid[self.current_tetromino.y + y][self.current_tetromino.x + x] = self.current_tetromino.color\n\n    def clear_lines(self):\n        lines_to_clear = [i for i, row in enumerate(self.grid) if all(row)]\n        for i in lines_to_clear:\n            del self.grid[i]\n            self.grid.insert(0, [0] * (SCREEN_WIDTH // BLOCK_SIZE))\n            self.score += 100\n\n    def run(self):\n        while self.running:\n            self.screen.fill(BLACK)\n            self.draw_grid()\n            self.draw_tetromino()\n            self.clear_lines()\n\n            for event in pygame.event.get():\n                if event.type == pygame.QUIT:\n                    self.running = False\n                if event.type == pygame.KEYDOWN:\n                    if event.key == pygame.K_LEFT:\n                        self.current_tetromino.x -= 1\n                        if self.check_collision():\n                            self.current_tetromino.x += 1\n                    if event.key == pygame.K_RIGHT:\n                        self.current_tetromino.x += 1\n                        if self.check_collision():\n                            self.current_tetromino.x -= 1\n                    if event.key == pygame.K_DOWN:\n   ...
#
# [Reviewer] 코드 검토 중
# --> 판정: reject
# Finished: Reviewer
#  {'decision': 'reject', 'review': '테스트상 3번 재검토 합니다.', 'count': 4}
#
# [Coder] 코드 작성 혹은 수정 중
# Finished: Coder
#  {'code': '```python\nimport pygame\nimport random\n\n# 게임 설정\nWIDTH, HEIGHT = 300, 600\nBLOCK_SIZE = 30\nFPS = 10\n\n# 색상 정의\nCOLORS = [\n    (0, 0, 0),   # 배경\n    (255, 0, 0), # 빨간색\n    (0, 255, 0), # 초록색\n    (0, 0, 255), # 파란색\n    (255, 255, 0), # 노란색\n    (255, 165, 0), # 주황색\n    (128, 0, 128), # 보라색\n]\n\n# Tetrimino 모양 정의\nTETROMINOS = [\n    [[1, 1, 1, 1]],                 # I 모양\n    [[1, 1, 1], [0, 1, 0]],         # T 모양\n    [[1, 1], [1, 1]],               # O 모양\n    [[0, 1, 1], [1, 1, 0]],         # S 모양\n    [[1, 1, 0], [0, 1, 1]],         # Z 모양\n    [[1, 0, 0], [1, 1, 1]],         # L 모양\n    [[0, 0, 1], [1, 1, 1]],         # J 모양\n]\n\nclass Tetris:\n    def __init__(self):\n        self.board = [[0] * (WIDTH // BLOCK_SIZE) for _ in range(HEIGHT // BLOCK_SIZE)]\n        self.current_tetromino = self.new_tetromino()\n        self.score = 0\n        \n    def new_tetromino(self):\n        shape = random.choice(TETROMINOS)\n        return {\'shape\': shape, \'x\': WIDTH // BLOCK_SIZE // 2 - len(shape[0]) // 2, \'y\': 0}\n\n    def rotate_tetromino(self):\n        self.current_tetromino[\'shape\'] = [list(row) for row in zip(*self.current_tetromino[\'shape\'][::-1])]\n\n    def move_tetromino(self, dx, dy):\n        self.current_tetromino[\'x\'] += dx\n        self.current_tetromino[\'y\'] += dy\n\n    def drop_tetromino(self):\n        self.current_tetromino[\'y\'] += 1\n\n    def clear_lines(self):\n        lines_to_clear = [i for i, row in enumerate(self.board) if all(row)]\n        for i in lines_to_clear:\n            del self.board[i]\n            self.board.insert(0, [0] * (WIDTH // BLOCK_SIZE))\n            self.score += 100\n\n    def game_over(self):\n        return any(self.board[0])\n\ndef draw_board(screen, board):\n    for y, row in enumerate(board):\n        for x, cell in enumerate(row):\n            pygame.draw.rect(screen, COLORS[cell], (x * BLOCK_SIZE, y * BLOCK_SIZE, BLOCK_SIZE, BLOCK_SIZE), 0)\n\ndef main():\n    pygame.init()\n    screen = pygame.display.set_mode((WIDTH, HEIGHT))\n    clock = pygame.time.Clock()\n    game = Tetris()\n\n    running = True\n    while running:\n        screen.fill(COLORS[0])\n        draw_board(screen, game.board)\n\n        for event in pygame.event.get():\n            if event.type == pygame.QUIT:\n                running = False\n\n        keys = pygame.key.get_pressed()\n        if keys[pygame.K_LEFT]:\n            game.move_tetromino(-1, 0)\n        if keys[pygame.K_RIGHT]:\n            game.move_tetromino(1, 0)\n        if keys[pygame.K_DOWN]:\n            game.drop_tetromino()\n        if keys[pygame.K_UP]:\n            game.rotate_tetromino()\n\n        game.clear_lines()\n        draw_board(screen, game.board)\n\n        pygame.display.flip()\n        clock.tick(FPS)\n\n        if game.game_over():\n            running = False\n\n    pygame.quit()\n\nif __name__ == "__main__":\n    main()\n```'}
#
# [Reviewer] 코드 검토 중
# Finished: Reviewer
#  {'decision': 'approve', 'review': '반복 횟수 초과로 승인합니다.'}
#
# [최종 완성 코드]
# ```python
# import pygame
# import random
#
# # 게임 설정
# WIDTH, HEIGHT = 300, 600
# BLOCK_SIZE = 30
# FPS = 10
#
# # 색상 정의
# COLORS = [
#     (0, 0, 0),   # 배경
#     (255, 0, 0), # 빨간색
#     (0, 255, 0), # 초록색
#     (0, 0, 255), # 파란색
#     (255, 255, 0), # 노란색
#     (255, 165, 0), # 주황색
#     (128, 0, 128), # 보라색
# ]
#
# # Tetrimino 모양 정의
# TETROMINOS = [
#     [[1, 1, 1, 1]],                 # I 모양
#     [[1, 1, 1], [0, 1, 0]],         # T 모양
#     [[1, 1], [1, 1]],               # O 모양
#     [[0, 1, 1], [1, 1, 0]],         # S 모양
#     [[1, 1, 0], [0, 1, 1]],         # Z 모양
#     [[1, 0, 0], [1, 1, 1]],         # L 모양
#     [[0, 0, 1], [1, 1, 1]],         # J 모양
# ]
#
# class Tetris:
#     def __init__(self):
#         self.board = [[0] * (WIDTH // BLOCK_SIZE) for _ in range(HEIGHT // BLOCK_SIZE)]
#         self.current_tetromino = self.new_tetromino()
#         self.score = 0
#
#     def new_tetromino(self):
#         shape = random.choice(TETROMINOS)
#         return {'shape': shape, 'x': WIDTH // BLOCK_SIZE // 2 - len(shape[0]) // 2, 'y': 0}
#
#     def rotate_tetromino(self):
#         self.current_tetromino['shape'] = [list(row) for row in zip(*self.current_tetromino['shape'][::-1])]
#
#     def move_tetromino(self, dx, dy):
#         self.current_tetromino['x'] += dx
#         self.current_tetromino['y'] += dy
#
#     def drop_tetromino(self):
#         self.current_tetromino['y'] += 1
#
#     def clear_lines(self):
#         lines_to_clear = [i for i, row in enumerate(self.board) if all(row)]
#         for i in lines_to_clear:
#             del self.board[i]
#             self.board.insert(0, [0] * (WIDTH // BLOCK_SIZE))
#             self.score += 100
#
#     def game_over(self):
#         return any(self.board[0])
#
# def draw_board(screen, board):
#     for y, row in enumerate(board):
#         for x, cell in enumerate(row):
#             pygame.draw.rect(screen, COLORS[cell], (x * BLOCK_SIZE, y * BLOCK_SIZE, BLOCK_SIZE, BLOCK_SIZE), 0)
#
# def main():
#     pygame.init()
#     screen = pygame.display.set_mode((WIDTH, HEIGHT))
#     clock = pygame.time.Clock()
#     game = Tetris()
#
#     running = True
#     while running:
#         screen.fill(COLORS[0])
#         draw_board(screen, game.board)
#
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 running = False
#
#         keys = pygame.key.get_pressed()
#         if keys[pygame.K_LEFT]:
#             game.move_tetromino(-1, 0)
#         if keys[pygame.K_RIGHT]:
#             game.move_tetromino(1, 0)
#         if keys[pygame.K_DOWN]:
#             game.drop_tetromino()
#         if keys[pygame.K_UP]:
#             game.rotate_tetromino()
#
#         game.clear_lines()
#         draw_board(screen, game.board)
#
#         pygame.display.flip()
#         clock.tick(FPS)
#
#         if game.game_over():
#             running = False
#
#     pygame.quit()
#
# if __name__ == "__main__":
#     main()
# ```
